# %%
from googleapiclient.discovery import build
import requests
import os
import pandas as pd
from IPython.display import JSON

# Data viz packages
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# NLP
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud

from idlelib import help
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\MI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\MI\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
api_key = "AIzaSyCfDnv7sfdog_RXAMynQeVhh2HPAVoXXls"

# %%
chnnl_ids = ['UCJskGeByzRRSvmOyZOz61ig',#more can be put here
            ]

# %%
api_service_name = "youtube"
api_version = "v3"

        # Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
# Function to get The Channel Statistics
def get_channel_stats(youtube,chnnl_ids):
    all_data = []
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(chnnl_ids)
    )
    response = request.execute()
    
    #loop through items
    for item in response['items']:
        data = {'ChannelName':item['snippet']['title'],
                'Subscribers':item['statistics']['subscriberCount'],
                'Views':item['statistics']['viewCount'],
                'TotalViews':item['statistics']['videoCount'],
                'PlaylistId':item['contentDetails']['relatedPlaylists']['uploads']
               }
        all_data.append(data)
    return(pd.DataFrame(all_data))

# %%
Channel_stats = get_channel_stats(youtube,chnnl_ids)
Channel_stats
# Out:
#       ChannelName Subscribers     Views TotalViews                PlaylistId
# 0  take U forward      507000  62256921        473  UUJskGeByzRRSvmOyZOz61ig

# %%
# Get all the uploaded Video IDs from the desired Playlist
playlist_id = "UUJskGeByzRRSvmOyZOz61ig"

def get_video_ids(youtube, playlist_id):
    video_ids = []

    # Fetch the initial page of results
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults=50
    )
    response = request.execute()

    # Extract video IDs from the response
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])

    # Fetch subsequent pages, if any
    while 'nextPageToken' in response:
        next_page_token = response['nextPageToken']
        request = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=playlist_id,
            maxResults=50,
            pageToken=next_page_token
        )
        response = request.execute()
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

    return video_ids

# %%
video_ids = get_video_ids(youtube,playlist_id)
# print(video_Ids)

# %%
# Function to get some basic Video Details
def get_video_details (youtube, video_ids) :
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
            
    return pd.DataFrame(all_video_info)

# %%
video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#         video_id    channelTitle  \
# 0    mG3KLugbOdc  take U forward
# 1    q570bKdrnlw  take U forward
# 2    8ocB7a_c-Cc  take U forward
# 3    ykelywHJWLg  take U forward
# 4    1zktEppsdig  take U forward
# ..           ...             ...
# 469  GAuI71n71Uc  take U forward
# 470  Cq_G2kk15U0  take U forward
# 471  SWABtcS8SU8  take U forward
# 472  TocJOW6vx_I  take U forward
# 473  VwylCVAVdmo  take U forward
#
#                                                  title  \
# 0    L28. Design a Browser History | LinkedList Imp...
# 1    L27. Clone a LinkedList with Next and Random P...
# 2    L26. Sort a Linked List | Merge Sort and Brute...
# 3    L24. Flattening a LinkedList | Multiple Approa...
# 4      L25. Merge K Sorted Lists | Multiple Approaches
# ..                                                 ...
# 469  How to get an internship at Amazon | Internshi...
# 470  How to approach people at Linkedin | How to bu...
# 471  Experience with Scaler Academy | More insights...
# 472      Longest Increasing Subsequence NlogN approach
# 473        Equal Average Partition Dynamic Programming
#
#                                            description  \
# 0    Problem Link: https://bit.ly/3tHiY6k\n\nEntire...
# 1    Problem Link: https://tinyurl.com/ytkm6xuz\n\n...
# 2    Problem Link: https://bit.ly/4aSKrTF\n\nEntire...
# 3    Problem Link: https://tinyurl.com/2p9ns48e\n\n...
# 4    Problem Link: https://bit.ly/4aCpvQx\n\nEntire...
# ..                                                 ...
# 469  Check our Website: https://www.takeuforward.or...
# 470  Check our Website: https://www.takeuforward.or...
# 471  Check our Website: https://www.takeuforward.or...
# 472  Check our Website: https://www.takeuforward.or...
# 473  Check our Website: https://www.takeuforward.or...
#
#                                                   tags           publishedAt  \
# 0    [linkedlist, dsa, linked list c++, linkedlist ...  2024-01-01T06:06:03Z
# 1    [linkedlist, dsa, linked list c++, linkedlist ...  2024-01-01T06:05:59Z
# 2    [linkedlist, dsa, linked list c++, linkedlist ...  2024-01-01T06:05:54Z
# 3    [linkedlist, dsa, linked list c++, linkedlist ...  2024-01-01T06:05:48Z
# 4    [linkedlist, dsa, linked list c++, linkedlist ...  2024-01-01T06:03:17Z
# ..                                                 ...                   ...
# 469          [Amazon, InterviewExperience, Internship]  2020-04-09T21:48:25Z
# 470                        [Linkedin, Referrals, Jobs]  2020-04-04T19:47:35Z
# 471                                               None  2020-04-01T04:30:14Z
# 472                                               None  2020-03-29T09:15:44Z
# 473  [DynamicProgramming, InterviewPreparation, DSA...  2020-03-23T04:31:04Z
#
#     viewCount likeCount favouriteCount commentCount  duration definition  \
# 0       30517       506           None           85  PT14M38S         hd
# 1       10016       344           None           21     PT33M         hd
# 2       14258       453           None           19  PT22M11S         hd
# 3        9748       399           None           30  PT32M58S         hd
# 4        7948       351           None           27   PT30M2S         hd
# ..        ...       ...            ...          ...       ...        ...
# 469    130638      7501           None          259   PT7M36S         hd
# 470     31906      2690           None           74   PT7M47S         hd
# 471    172723      None           None          608  PT29M51S         hd
# 472     67066      1858           None          141   PT4M38S         hd
# 473     22273       683           None           62  PT18M54S         hd
#
#     caption
# 0     false
# 1     false
# 2     false
# 3     false
# 4     false
# ..      ...
# 469   false
# 470   false
# 471   false
# 472   false
# 473   false
#
# [474 rows x 13 columns]

# %% [markdown]
# ## Data Pre-Processing

# %%
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount          True
# favouriteCount     True
# commentCount      False
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric,errors='coerce', axis=1)

# %%
from dateutil import parser

# %%
#Publish Day in the Week
video_df['publishedAt'] = video_df['publishedAt'].astype(str)
video_df['publishedAt'] = video_df['publishedAt'].apply(lambda x: parser.parse(x)) 
video_df['publishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
# Add Video Durations
import isodate
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df[['durationSecs', 'duration']]
# Out:
#        durationSecs  duration
# 0   0 days 00:14:38  PT14M38S
# 1   0 days 00:33:00     PT33M
# 2   0 days 00:22:11  PT22M11S
# 3   0 days 00:32:58  PT32M58S
# 4   0 days 00:30:02   PT30M2S
# ..              ...       ...
# 469 0 days 00:07:36   PT7M36S
# 470 0 days 00:07:47   PT7M47S
# 471 0 days 00:29:51  PT29M51S
# 472 0 days 00:04:38   PT4M38S
# 473 0 days 00:18:54  PT18M54S
#
# [474 rows x 2 columns]

# %%
# Add Tag Count
video_df['TagCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
video_df
# Out:
#         video_id    channelTitle  \
# 0    mG3KLugbOdc  take U forward
# 1    q570bKdrnlw  take U forward
# 2    8ocB7a_c-Cc  take U forward
# 3    ykelywHJWLg  take U forward
# 4    1zktEppsdig  take U forward
# ..           ...             ...
# 469  GAuI71n71Uc  take U forward
# 470  Cq_G2kk15U0  take U forward
# 471  SWABtcS8SU8  take U forward
# 472  TocJOW6vx_I  take U forward
# 473  VwylCVAVdmo  take U forward
#
#                                                  title  \
# 0    L28. Design a Browser History | LinkedList Imp...
# 1    L27. Clone a LinkedList with Next and Random P...
# 2    L26. Sort a Linked List | Merge Sort and Brute...
# 3    L24. Flattening a LinkedList | Multiple Approa...
# 4      L25. Merge K Sorted Lists | Multiple Approaches
# ..                                                 ...
# 469  How to get an internship at Amazon | Internshi...
# 470  How to approach people at Linkedin | How to bu...
# 471  Experience with Scaler Academy | More insights...
# 472      Longest Increasing Subsequence NlogN approach
# 473        Equal Average Partition Dynamic Programming
#
#                                            description  \
# 0    Problem Link: https://bit.ly/3tHiY6k\n\nEntire...
# 1    Problem Link: https://tinyurl.com/ytkm6xuz\n\n...
# 2    Problem Link: https://bit.ly/4aSKrTF\n\nEntire...
# 3    Problem Link: https://tinyurl.com/2p9ns48e\n\n...
# 4    Problem Link: https://bit.ly/4aCpvQx\n\nEntire...
# ..                                                 ...
# 469  Check our Website: https://www.takeuforward.or...
# 470  Check our Website: https://www.takeuforward.or...
# 471  Check our Website: https://www.takeuforward.or...
# 472  Check our Website: https://www.takeuforward.or...
# 473  Check our Website: https://www.takeuforward.or...
#
#                                                   tags  \
# 0    [linkedlist, dsa, linked list c++, linkedlist ...
# 1    [linkedlist, dsa, linked list c++, linkedlist ...
# 2    [linkedlist, dsa, linked list c++, linkedlist ...
# 3    [linkedlist, dsa, linked list c++, linkedlist ...
# 4    [linkedlist, dsa, linked list c++, linkedlist ...
# ..                                                 ...
# 469          [Amazon, InterviewExperience, Internship]
# 470                        [Linkedin, Referrals, Jobs]
# 471                                               None
# 472                                               None
# 473  [DynamicProgramming, InterviewPreparation, DSA...
#
#                   publishedAt  viewCount  likeCount  favouriteCount  \
# 0   2024-01-01 06:06:03+00:00    30517.0      506.0             NaN
# 1   2024-01-01 06:05:59+00:00    10016.0      344.0             NaN
# 2   2024-01-01 06:05:54+00:00    14258.0      453.0             NaN
# 3   2024-01-01 06:05:48+00:00     9748.0      399.0             NaN
# 4   2024-01-01 06:03:17+00:00     7948.0      351.0             NaN
# ..                        ...        ...        ...             ...
# 469 2020-04-09 21:48:25+00:00   130638.0     7501.0             NaN
# 470 2020-04-04 19:47:35+00:00    31906.0     2690.0             NaN
# 471 2020-04-01 04:30:14+00:00   172723.0        NaN             NaN
# 472 2020-03-29 09:15:44+00:00    67066.0     1858.0             NaN
# 473 2020-03-23 04:31:04+00:00    22273.0      683.0             NaN
#
#      commentCount  duration definition caption    durationSecs  TagCount  \
# 0            85.0  PT14M38S         hd   false 0 days 00:14:38        18
# 1            21.0     PT33M         hd   false 0 days 00:33:00        18
# 2            19.0  PT22M11S         hd   false 0 days 00:22:11        19
# 3            30.0  PT32M58S         hd   false 0 days 00:32:58        19
# 4            27.0   PT30M2S         hd   false 0 days 00:30:02        19
# ..            ...       ...        ...     ...             ...       ...
# 469         259.0   PT7M36S         hd   false 0 days 00:07:36         3
# 470          74.0   PT7M47S         hd   false 0 days 00:07:47         3
# 471         608.0  PT29M51S         hd   false 0 days 00:29:51         0
# 472         141.0   PT4M38S         hd   false 0 days 00:04:38         0
# 473          62.0  PT18M54S         hd   false 0 days 00:18:54         4
#
#                                     title_no_stopwords publishDayName
# 0    [L28., Design, Browser, History, |, LinkedList...         Monday
# 1    [L27., Clone, LinkedList, Next, Random, Pointe...         Monday
# 2    [L26., Sort, Linked, List, |, Merge, Sort, Bru...         Monday
# 3    [L24., Flattening, LinkedList, |, Multiple, Ap...         Monday
# 4    [L25., Merge, K, Sorted, Lists, |, Multiple, A...         Monday
# ..                                                 ...            ...
# 469  [How, get, internship, Amazon, |, Internship, ...       Thursday
# 470  [How, approach, people, Linkedin, |, How, buil...       Saturday
# 471  [Experience, Scaler, Academy, |, More, insight...      Wednesday
# 472  [Longest, Increasing, Subsequence, NlogN, appr...         Sunday
# 473  [Equal, Average, Partition, Dynamic, Programming]         Monday
#
# [474 rows x 17 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Best Performing Videos

# %%
ax = sns.barplot(x='title', y='viewCount', data = video_df.sort_values('viewCount', ascending=False)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# ## Worst Performing Videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=True)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# ## View Distribution Per Video

# %%
sns.violinplot(x=video_df['channelTitle'], y=video_df['viewCount'])
# Out:
# <Axes: xlabel='channelTitle', ylabel='viewCount'>

# %% [markdown]
# ## Views VS Likes and Comments

# %%
fig, ax = plt.subplots(1,2)
sns.scatterplot(data = video_df, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = video_df, x = 'likeCount', y = 'viewCount', ax = ax[1])
# Out:
# <Axes: xlabel='likeCount', ylabel='viewCount'>

# %% [markdown]
# ## Video Duration

# %%
sns.histplot(data = video_df, x = 'durationSecs', bins=30)
# Out:
# <Axes: xlabel='durationSecs', ylabel='Count'>

# %% [markdown]
# ## WorldCloud for Video Titles

# %%
stop_words = set(stopwords.words('english'))
video_df['title_no_stopwords'] = video_df['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in video_df['title_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words) 

def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis("off");

wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)

# %% [markdown]
# ## Upload Schedule

# %%
day_df = pd.DataFrame(video_df['publishDayName'].value_counts())
weekdays = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays)
ax = day_df.plot.bar(rot=0)
ax.set_xlabel('index')
ax.set_ylabel('publishDayName')
# Out:
# Text(0, 0.5, 'publishDayName')
